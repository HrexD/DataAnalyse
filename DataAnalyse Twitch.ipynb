# %%
import pandas as pd
import seaborn as sb
import matplotlib as mpl
import numpy as np

import csv
df=pd.read_csv(r'.\Twitch_game_data.csv',encoding='cp1252')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 7
#       4 import numpy as np
#       6 import csv
# ----> 7 df=pd.read_csv(r'.\Twitch_game_data.csv',encoding='cp1252')
#
# AttributeError: module 'pandas' has no attribute 'read_csv'

# %%
df
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 14395   196                       Garry's Mod     12  2021         630902
# 14396   197  Call of Duty: Black Ops Cold War     12  2021         622497
# 14397   198                             Noita     12  2021         620983
# 14398   199                 Pro Soccer Online     12  2021         619859
# 14399   200              Pokemon Sword/Shield     12  2021         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
df_2016=df[df['Year']==2016]

# %%
df_2016
# Out:
#       Rank                              Game  Month  Year  Hours_watched  \
# 0        1                 League of Legends      1  2016       94377226
# 1        2  Counter-Strike: Global Offensive      1  2016       47832863
# 2        3                            Dota 2      1  2016       45185893
# 3        4                       Hearthstone      1  2016       39936159
# 4        5       Call of Duty: Black Ops III      1  2016       16153057
# ...    ...                               ...    ...   ...            ...
# 2395   196     Grand Theft Auto: San Andreas     12  2016         140340
# 2396   197                          PAYDAY 2     12  2016         138698
# 2397   198                   Life is Strange     12  2016         137714
# 2398   199                         Undertale     12  2016         136892
# 2399   200                XCOM: Enemy Within     12  2016         135948
#
#      Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
df_2016=df.query("Year == 2016 and Game == 'League of Legends'")
df_2017=df.query("Year == 2017 and Game == 'League of Legends'")
df_2018=df.query("Year == 2018 and Game == 'League of Legends'")
df_2019=df.query("Year == 2019 and Game == 'League of Legends'")
df_2020=df.query("Year == 2020 and Game == 'League of Legends'")
df_2021=df.query("Year == 2021 and Game == 'League of Legends'")
df_means_2016=df_2016['Hours_watched'].mean()
df_means_2017=df_2017['Hours_watched'].mean()
df_means_2018=df_2018['Hours_watched'].mean()
df_means_2019=df_2019['Hours_watched'].mean()
df_means_2020=df_2020['Hours_watched'].mean()
df_means_2021=df_2021['Hours_watched'].mean()

# %%
print(df_means_2016,
df_means_2017,
df_means_2018,
df_means_2019,
df_means_2020,
df_means_2021)
# Out:
# 86289154.16666667 85199882.91666667 82115057.08333333 93202962.16666667 129461377.66666667 144638425.41666666

# %%
df.describe()
# Out:
#               Rank         Month          Year  Hours_watched  Peak_viewers  \
# count  14400.00000  14400.000000  14400.000000   1.440000e+04  1.440000e+04
# mean     100.50000      6.500000   2018.500000   4.782448e+06  5.509512e+04
# std       57.73631      3.452172      1.707884   1.667895e+07  1.329134e+05
# min        1.00000      1.000000   2016.000000   8.981100e+04  4.410000e+02
# 25%       50.75000      3.750000   2017.000000   3.680565e+05  8.352500e+03
# 50%      100.50000      6.500000   2018.500000   8.198695e+05  2.016950e+04
# 75%      150.25000      9.250000   2020.000000   2.295376e+06  4.598150e+04
# max      200.00000     12.000000   2021.000000   3.445520e+08  3.123208e+06
#
#        Peak_channels     Streamers    Avg_viewers  Avg_channels  \
# count   14400.000000  1.440000e+04   14400.000000  14400.000000
# mean      586.759236  1.722478e+04    6553.785278    214.859097
# std      2721.411089  5.453153e+04   22858.599426    743.850310
# ...

# %%
df_2016
# Out:
#       Rank               Game  Month  Year  Hours_watched Hours_Streamed  \
# 0        1  League of Legends      1  2016       94377226  1362044 hours
# 200      1  League of Legends      2  2016       93154772  1266715 hours
# 400      1  League of Legends      3  2016       94514511  1264029 hours
# 600      1  League of Legends      4  2016       88389049  1217250 hours
# 800      1  League of Legends      5  2016       80679320  1196096 hours
# 1000     1  League of Legends      6  2016       81348505  1037242 hours
# 1200     1  League of Legends      7  2016       77871713  1004238 hours
# 1400     1  League of Legends      8  2016       81684707  1097258 hours
# 1600     1  League of Legends      9  2016       81064642  1087244 hours
# 1800     1  League of Legends     10  2016      104305242  1155966 hours
# 2000     1  League of Legends     11  2016       76730765  1127714 hours
# 2200     1  League of Legends     12  2016       81349398  1241696 hours
#
# ...

# %%
sb.relplot(data=df_2016, x="Month", y="Hours_watched" )

# %%
sb.barplot(data=df_2016, x="Month", y="Hours_watched",  )
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Hours_watched'>

# %%
df_lol=df.query("Game == 'League of Legends'")

# %%
sb.barplot(data=df_lol, x="Year", y="Hours_watched", hue="Month", estimator='mean')
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Hours_watched'>
